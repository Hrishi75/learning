# %%
import numpy as np

# %%
a = np.array([1,2,3,4])
print(a)
print(a.shape)
print(a.dtype)
# Out:
# [1 2 3 4]
# (4,)
# int64

# %%
m = np.array([[1,2,3],
              [4,5,6]])
print(a.shape)
# Out:
# (4,)
